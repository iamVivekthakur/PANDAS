# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # SCATTER PLOT

# %% [markdown]
# When we study the realtionship between two contionus variables.

# %%
df=sns.load_dataset("tips")
df.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3

# %%
plt.figure(figsize=(10,5))
plt.plot(df["total_bill"],df["tip"],'^g')
plt.xlabel("Total_bill", fontsize=10)
plt.ylabel("Tip")
plt.xlabel("total_bil")
# Out:
# Text(0.5, 0, 'total_bil')

# %%
plt.figure(figsize=(10,5))
plt.scatter(df["total_bill"],df["tip"]);

# %%
plt.figure(figsize=(10,5))
plt.scatter(df["total_bill"],df["tip"]);

# %% [markdown]
# # HISTOGRAM

# %%
df1=sns.load_dataset("flights")

# %%
plt.hist(df1["year"]);

# %% [markdown]
# # BAR CHART

# %%
plt.bar(df["smoker"],df["tip"]);

# %%
plt.barh(df["smoker"],df["tip"]);

# %% [markdown]
# # STAG BAR

# %%
iris=sns.load_dataset("iris")

# %%
plt.bar(iris["species"],iris["sepal_length"])
plt.bar(iris["species"],iris["sepal_width"],bottom=iris["sepal_length"]);

# %%
plt.bar(iris["species"],iris["sepal_length"])
plt.bar(iris["species"],iris["sepal_width"]);
