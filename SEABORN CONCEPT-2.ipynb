# %% [markdown]
# # SEABORN

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
data=pd.read_csv("C:\\Users\\user\\OneDrive\\Desktop\\madrid software\\MADRID CLASSES\\Data set\\Advertising.csv",index_col=0)
data
# Out:
#         TV  radio  newspaper  sales
# 1    230.1   37.8       69.2   22.1
# 2     44.5   39.3       45.1   10.4
# 3     17.2   45.9       69.3    9.3
# 4    151.5   41.3       58.5   18.5
# 5    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 196   38.2    3.7       13.8    7.6
# 197   94.2    4.9        8.1    9.7
# 198  177.0    9.3        6.4   12.8
# 199  283.6   42.0       66.2   25.5
# 200  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %%
sns.relplot(x="TV",y="sales", data=data);

# %%
sns.relplot(x="radio",y="sales", data=data);

# %%
sns.pairplot(data); #not much in use

# %%
tips=sns.load_dataset("tips")

# %%
sns.barplot(x="day",y="tip",data=tips, hue="sex");

# %%
sns.barplot(x="day",y="tip",data=tips, hue="smoker");

# %% [markdown]
# NOTE :-
#
# THE DIFFERENCE BETWEEN MAT PLOT'S BARPLOT AND SEABORN BAR PLOT IS SEABORN BAR PLOT WILL SHOW THE AVERAGE VALUE BAR PLOT.

# %%
plt.figure(figsize=(10,5))
sns.boxplot(x="day", y="tip", data=tips);

# %%
fmri=sns.load_dataset("fmri")
fmri
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %%
sns.lineplot(x="timepoint",y="signal",data=fmri, ci=False);

# %%
fmri.describe()
# Out:
#          timepoint       signal
# count  1064.000000  1064.000000
# mean      9.000000     0.003540
# std       5.479801     0.093930
# min       0.000000    -0.255486
# 25%       4.000000    -0.046070
# 50%       9.000000    -0.013653
# 75%      14.000000     0.024293
# max      18.000000     0.564985
