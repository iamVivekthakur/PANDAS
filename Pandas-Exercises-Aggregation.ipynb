# %% [markdown]
# # Aggregations

# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset occupation.csv from the folder or [here](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user).

# %%
df=pd.read_csv("C:\\Users\\user\\OneDrive\\Desktop\\madrid software\\MADRID CLASSES\\PYTHON ASSIGNMENTS AND TEST\\2. Pandas Basic Exercises-20211223T080106Z-001 (1)\\2. Pandas Basic Exercises\\Exercise Data Files\\Pandas Exercise Aggregation Files\\occupation.csv", sep="|")
df
# Out:
#      user_id  age gender     occupation zip_code
# 0          1   24      M     technician    85711
# 1          2   53      F          other    94043
# 2          3   23      M         writer    32067
# 3          4   24      M     technician    43537
# 4          5   33      F          other    15213
# ..       ...  ...    ...            ...      ...
# 938      939   26      F        student    33319
# 939      940   32      M  administrator    02215
# 940      941   20      M        student    97229
# 941      942   48      F      librarian    78209
# 942      943   22      M        student    77841
#
# [943 rows x 5 columns]

# %% [markdown]
# ### Step 3. Assign it to a variable called users.

# %%
df
# Out:
#      user_id  age gender     occupation zip_code
# 0          1   24      M     technician    85711
# 1          2   53      F          other    94043
# 2          3   23      M         writer    32067
# 3          4   24      M     technician    43537
# 4          5   33      F          other    15213
# ..       ...  ...    ...            ...      ...
# 938      939   26      F        student    33319
# 939      940   32      M  administrator    02215
# 940      941   20      M        student    97229
# 941      942   48      F      librarian    78209
# 942      943   22      M        student    77841
#
# [943 rows x 5 columns]

# %% [markdown]
# ### Step 4. Discover what is the mean age per occupation

# %%
df.groupby(["occupation"])["age"].mean()
# Out:
# occupation
# administrator    38.746835
# artist           31.392857
# doctor           43.571429
# educator         42.010526
# engineer         36.388060
# entertainment    29.222222
# executive        38.718750
# healthcare       41.562500
# homemaker        32.571429
# lawyer           36.750000
# librarian        40.000000
# marketing        37.615385
# none             26.555556
# other            34.523810
# programmer       33.121212
# retired          63.071429
# salesman         35.666667
# scientist        35.548387
# student          22.081633
# technician       33.148148
# writer           36.311111
# Name: age, dtype: float64

# %% [markdown]
# ### Step 5. Discover the Male ratio per occupation and sort it from the most to the least.
#
# Use numpy.where() to encode gender column.

# %%
out1=df.groupby(by=["occupation","gender"])[["gender"]].count().add_prefix("CountOf_").reset_index()

# %%
out2 = out1.pivot(index="occupation",columns="gender",values="CountOf_gender")
# Out:
# gender            F      M
# occupation
# administrator  36.0   43.0
# artist         13.0   15.0
# doctor          NaN    7.0
# educator       26.0   69.0
# engineer        2.0   65.0
# entertainment   2.0   16.0
# executive       3.0   29.0
# healthcare     11.0    5.0
# homemaker       6.0    1.0
# lawyer          2.0   10.0
# librarian      29.0   22.0
# marketing      10.0   16.0
# none            4.0    5.0
# other          36.0   69.0
# programmer      6.0   60.0
# retired         1.0   13.0
# salesman        3.0    9.0
# scientist       3.0   28.0
# student        60.0  136.0
# technician      1.0   26.0
# writer         19.0   26.0

# %%
data
# Out:
#      index     occupation
# 0        0     technician
# 1        2         writer
# 2        3     technician
# 3        5      executive
# 4        6  administrator
# ..     ...            ...
# 665    935          other
# 666    936       educator
# 667    939  administrator
# 668    940        student
# 669    942        student
#
# [670 rows x 2 columns]

# %% [markdown]
# ### Step 6. For each occupation, calculate the minimum and maximum ages

# %%
data1= df.groupby(by="occupation")[["age"]].min().add_prefix("Min_")
data2 = df.groupby(by="occupation")[["age"]].max().add_prefix("Max_")
Data = pd.concat([data1,data2],axis=1)
Data
# Out:
#                Min_age  Max_age
# occupation
# administrator       21       70
# artist              19       48
# doctor              28       64
# educator            23       63
# engineer            22       70
# entertainment       15       50
# executive           22       69
# healthcare          22       62
# homemaker           20       50
# lawyer              21       53
# librarian           23       69
# marketing           24       55
# none                11       55
# other               13       64
# programmer          20       63
# retired             51       73
# salesman            18       66
# scientist           23       55
# student              7       42
# technician          21       55
# writer              18       60

# %% [markdown]
# ### Step 7. For each combination of occupation and gender, calculate the mean age

# %%
df.groupby(["occupation","gender"])["age"].mean()
# Out:
# occupation     gender
# administrator  F         40.638889
#                M         37.162791
# artist         F         30.307692
#                M         32.333333
# doctor         M         43.571429
# educator       F         39.115385
#                M         43.101449
# engineer       F         29.500000
#                M         36.600000
# entertainment  F         31.000000
#                M         29.000000
# executive      F         44.000000
#                M         38.172414
# healthcare     F         39.818182
#                M         45.400000
# homemaker      F         34.166667
#                M         23.000000
# lawyer         F         39.500000
#                M         36.200000
# librarian      F         40.000000
#                M         40.000000
# marketing      F         37.200000
#                M         37.875000
# none           F         36.500000
#                M         18.600000
# other          F         35.472222
# ...

# %% [markdown]
# ### Step 8.  For each occupation present the percentage of women and men

# %%
res3 = round(res2*100,2)
res4 = 100-res3
user_tab = pd.concat([res3,res4],axis=1).reset_index()
