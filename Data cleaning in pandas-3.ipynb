# %%
import numpy as np
import pandas as pd 
import seaborn as sns

# %%
df=sns.load_dataset("titanic")
df.head(2)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False

# %%
df.drop(columns=["deck"],inplace=True)

# %%
df.head(1)
# Out:
#    survived  pclass   sex   age  sibsp  parch  fare embarked  class  who  \
# 0         0       3  male  22.0      1      0  7.25        S  Third  man
#
#    adult_male  embark_town alive  alone
# 0        True  Southampton    no  False

# %%
# if you want to see information with respect of two columns
df.groupby(["embark_town"])["survived"].value_counts()
# Out:
# embark_town  survived
# Cherbourg    1            93
#              0            75
# Queenstown   0            47
#              1            30
# Southampton  0           427
#              1           217
# Name: survived, dtype: int64

# %%
df.groupby("pclass")["fare"].agg(["min","max","mean"])
# Out:
#         min       max       mean
# pclass
# 1       0.0  512.3292  84.154687
# 2       0.0   73.5000  20.662183
# 3       0.0   69.5500  13.675550

# %%
len(df[df["fare"]==0.0]["who"])
# Out:
# 15

# %%
df[(df["fare"]>=512) & (df["parch"]>0) & (df["sibsp"]>0)]
# Out:
# Empty DataFrame
# Columns: [survived, pclass, sex, age, sibsp, parch, fare, embarked, class, who, adult_male, embark_town, alive, alone]
# Index: []

# %%
df[(df["fare"]>=512) & (df["parch"]>0) | (df["sibsp"]>0)]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 7           0       3    male   2.0      3      1  21.0750        S   Third
# 9           1       2  female  14.0      1      0  30.0708        C  Second
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 866         1       2  female  27.0      1      0  13.8583        C  Second
# 869         1       3    male   4.0      1      1  11.1333        S   Third
# 871         1       1  female  47.0      1      1  52.5542        S   First
# 874         1       2  female  28.0      1      0  24.0000        C  Second
# 888         0       3  female   NaN      1      2  23.4500        S   Third
#
#        who  adult_male  embark_town alive  alone
# ...

# %%
df[df["fare"]>=512]
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked  class  \
# 258         1       1  female  35.0      0      0  512.3292        C  First
# 679         1       1    male  36.0      0      1  512.3292        C  First
# 737         1       1    male  35.0      0      0  512.3292        C  First
#
#        who  adult_male embark_town alive  alone
# 258  woman       False   Cherbourg   yes   True
# 679    man        True   Cherbourg   yes  False
# 737    man        True   Cherbourg   yes   True

# %% [markdown]
# # for indexing there is loc and iloc
#
# loc= named index
#
# iloc=numerical index

# %%
df.iloc[:2] # it is in series
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
#
#      who  adult_male  embark_town alive  alone
# 0    man        True  Southampton    no  False
# 1  woman       False    Cherbourg   yes  False

# %%
df.iloc[[2]]  # to make dataframe
# Out:
#    survived  pclass     sex   age  sibsp  parch   fare embarked  class    who  \
# 2         1       3  female  26.0      0      0  7.925        S  Third  woman
#
#    adult_male  embark_town alive  alone
# 2       False  Southampton   yes   True

# %%
df.iloc[10:16,:7]
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare
# 10         1       3  female   4.0      1      1  16.7000
# 11         1       1  female  58.0      0      0  26.5500
# 12         0       3    male  20.0      0      0   8.0500
# 13         0       3    male  39.0      1      5  31.2750
# 14         0       3  female  14.0      0      0   7.8542
# 15         1       2  female  55.0      0      0  16.0000

# %%
df.loc[:2]
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
#
#      who  adult_male  embark_town alive  alone
# 0    man        True  Southampton    no  False
# 1  woman       False    Cherbourg   yes  False
# 2  woman       False  Southampton   yes   True

# %%
df1=pd.DataFrame({"name":["a","b","c","d"], "studid":[1,2,3,4],"age":[12,13,14,15]})
df1.set_index("name",inplace=True)
df1
# Out:
#       studid  age
# name
# a          1   12
# b          2   13
# c          3   14
# d          4   15

# %%
df1.loc["b":"c"]
# Out:
#       studid  age
# name
# b          2   13
# c          3   14

# %%
df1.iloc[1:3]
# Out:
#       studid  age
# name
# b          2   13
# c          3   14

# %%
df1.drop("d") # to drop rows
# Out:
#       studid  age
# name
# a          1   12
# b          2   13
# c          3   14

# %%
df1.filter(items=["age"])
# Out:
#       age
# name
# a      12
# b      13
# c      14
# d      15

# %%
df.embark_town.nunique() #to know number of unique value in particular column
# Out:
# 3

# %%
df1["log_values"]= pd.Series([50,20,30,40])
df1.reset_index(drop=True,inplace=True)
df1
# Out:
#    studid  age  log_values
# 0       1   12         NaN
# 1       2   13         NaN
# 2       3   14         NaN
# 3       4   15         NaN

# %%
df.iloc[np.where(df["fare"]==max(df["fare"]))]
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked  class  \
# 258         1       1  female  35.0      0      0  512.3292        C  First
# 679         1       1    male  36.0      0      1  512.3292        C  First
# 737         1       1    male  35.0      0      0  512.3292        C  First
#
#        who  adult_male embark_town alive  alone
# 258  woman       False   Cherbourg   yes   True
# 679    man        True   Cherbourg   yes  False
# 737    man        True   Cherbourg   yes   True
